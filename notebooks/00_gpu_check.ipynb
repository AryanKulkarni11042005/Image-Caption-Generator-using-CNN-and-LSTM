# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# 2.11.0+cu128
# 12.8
# True

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
props = torch.cuda.get_device_properties(0)
print(props.name)
print(f"{props.total_memory / 1024**3:.2f} GB")
print(f"compute capability {props.major}.{props.minor}")
# Out:
# NVIDIA GeForce RTX 3050 4GB Laptop GPU
# 4.00 GB
# compute capability 8.6

# %%
a = torch.randn(3, 3, device=device)                  # lives on CPU
b = torch.randn(3, 3, device=device)   # lives on GPU
a @ b
# Out:
# tensor([[ 0.2269,  0.6930,  0.9181],
#         [-0.3659,  0.6634,  2.6989],
#         [-0.3202, -1.6677, -2.7273]], device='cuda:0')

# %%
import time
x = torch.randn(4096, 4096, device = device)

t = time.time()
y = x @ x
torch.cuda.synchronize()
print(f"{(time.time() - t)*1000:.2f} ms")
# Out:
# 53.95 ms

# %%
print(f"allocated: {torch.cuda.memory_allocated()/1024**2:.1f} MB")
print(f"reserved:  {torch.cuda.memory_reserved()/1024**2:.1f} MB")
del x, y
print(f"allocated: {torch.cuda.memory_allocated()/1024**2:.1f} MB")
print(f"reserved:  {torch.cuda.memory_reserved()/1024**2:.1f} MB")
# Out:
# allocated: 136.1 MB
# reserved:  214.0 MB
# allocated: 8.1 MB
# reserved:  214.0 MB
